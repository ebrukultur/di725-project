# %% [markdown]
# ## Load the Google Drive Helper and Mount

# %%
#  using Google Colab - Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Required Packages

# %%
# !pip install huggingface-hub
# !huggingface-cli login
# Out:
# ...
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `di725-project` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...

# %%
# !pip install evaluate
# !pip install pycocoevalcap
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 24.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Preprocessing the RISC Dataset

# %% [markdown]
# **Imports & Load Data**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import os
import wandb

# %%
# !python '/content/drive/MyDrive/DI 725 Project/preprocess.py' --input_csv '/content/drive/MyDrive/DI 725 Project/data/captions.csv'

# %% [raw]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=all_captions.txt --model_prefix=risc_spm --vocab_size=2000
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: all_captions.txt
#   input_format:
#   model_prefix: risc_spm
#   model_type: UNIGRAM
#   vocab_size: 2000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: all_captions.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 211214 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=12068870
# trainer_interface.cc(550) LOG(INFO) Done: 99.9842% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=26
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999842
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 211214 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=9885019
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 10165 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 211214
# trainer_interface.cc(609) LOG(INFO) Done! 3869
# unigram_model_trainer.cc(602) LOG(INFO) Using 3869 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=4783 obj=7.34153 num_tokens=7382 num_tokens/piece=1.54338
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=3265 obj=5.47305 num_tokens=7283 num_tokens/piece=2.23063
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=2447 obj=5.42894 num_tokens=7650 num_tokens/piece=3.12628
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=2447 obj=5.3866 num_tokens=7650 num_tokens/piece=3.12628
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=2200 obj=5.38331 num_tokens=8090 num_tokens/piece=3.67727
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=2200 obj=5.38086 num_tokens=8089 num_tokens/piece=3.67682
# trainer_interface.cc(687) LOG(INFO) Saving model: risc_spm.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: risc_spm.vocab
# Processed captions saved to /content/drive/MyDrive/DI 725 Project/data/captions_processed.csv
# Processed captions saved to /content/drive/MyDrive/DI 725 Project/data/captions_processed.csv

# %%
captions_processed_csv = "/content/drive/MyDrive/DI 725 Project/data/captions_processed.csv"
# Load captions DataFrame
df_p = pd.read_csv(captions_processed_csv)

# %%
df_p.head()

# %% [raw]
# image	caption_id	syn_tokens	split
# 0	NWPU_31430.jpg	caption_1	['-1', 'forty', 'twenty-eight', '109', '-1', '...	test
# 1	NWPU_31431.jpg	caption_1	['one', 'fifty-one', '-1', 'forty-six', '-1', ...	test
# 2	NWPU_31432.jpg	caption_1	['-1', 'twenty-eight', 'forty-six', '-1', '-1'...	test
# 3	NWPU_31433.jpg	caption_1	['-1', 'fifty-one', 'twenty-eight', '-1', '-1'...	test
# 4	NWPU_31434.jpg	caption_1	['-1', '-1', 'forty-six', '-1', '-1', 'sixty-s...	test

# %%
captions_csv = "/content/drive/MyDrive/DI 725 Project/data/captions.csv"
# Load captions DataFrame
df_raw_f = pd.read_csv(captions_csv)

# %%
df_raw_f.head()

# %% [raw]
# source	split	image	caption_1	caption_2	caption_3	caption_4	caption_5
# 0	NWPU	test	NWPU_31430.jpg	A gray plane on the runway and the lawn beside .	A grey plane is on the runway by the lawn .	There is an airplane on the runway with a larg...	A plane is parked on the runway next to the gr...	There is a plane on the runway beside the grass .
# 1	NWPU	test	NWPU_31431.jpg	Three small planes parked in a line on the air...	There are four aircraft on the open ground, Th...	There are many planes of different sizes in a ...	Four planes are parked on the runway .	Four planes of different sizes were on the mar...
# 2	NWPU	test	NWPU_31432.jpg	A plane parked in a line on the airport with s...	A white plane was parked on the instruction li...	An airplane parked in an open area with many c...	A plane is parked on the open space .	There is 1 plane on the ground marked .
# 3	NWPU	test	NWPU_31433.jpg	A small plane and a big plane parked next to b...	A white plane and a gray plane parked at the b...	Two planes of different sizes are neatly parke...	A large plane and a small plane are parked nea...	Two planes are on the marked ground .
# 4	NWPU	test	NWPU_31434.jpg	Two planes parked next to boarding bridges .	Two aircraft were parked at the departure gates .	Two planes of different sizes are neatly parke...	Two planes are parked next to the terminal .	Two planes are on the marked ground .

# %% [markdown]
# ## Running the Code for Fine-tuning with LoRA

# %%
# !python "/content/drive/MyDrive/DI 725 Project/train_lora.py" \ # the training script
  --csv "/content/drive/MyDrive/DI 725 Project/data/captions_processed.csv" \ 
  --images_dir "/content/drive/MyDrive/DI 725 Project/data/resized" \
  --model_name "google/paligemma2-3b-pt-224" \
  --output_dir "/content/drive/MyDrive/DI 725 Project/out/lora_r2_alpha_4" \ # change it according to the selected model 
  --wandb_project "di725-project" \
  --run_name "phase2-lora-r2-alpha-4" \ # change it according to the selected model 
  --train_bs 4 \ # training batch size - kept constant for all experiments
  --eval_bs 4 \ # evaluation batch size - kept constant for all experiments
  --epochs 1 \ # number of epochs - kept constant for all experiments
  --lr 5e-5 \ # learning rate - kept constant for all experiments
  --lora_r 2 \ # lora rank - adjusted during experiments
  --lora_alpha 4 \ # lora alpha - adjusted during experiments
  --lora_dropout 0.1 \ # lora dropout - adjusted during experiments
  --gradient_accumulation_steps 4 # kept constant for all experiments
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# You are passing both `text` and `images` to `PaliGemmaProcessor`. The processor expects special image tokens in the text, as many tokens as there are images per each text. It is recommended to add `` tokens in the very beginning of your text. For this call, we will infer how many images each text has and add special tokens.
# You are passing both `text` and `images` to `PaliGemmaProcessor`. The processor expects special image tokens in the text, as many tokens as there are images per each text. It is recommended to add `` tokens in the very beginning of your text. For this call, we will infer how many images each text has and add special tokens.
# ...

# %% [markdown]
# ## Base Model PaliGemma Inference

# %%
# !python "/content/drive/MyDrive/DI 725 Project/eval_baseline.py"

# %% [markdown]
# 2025-05-18 15:29:55.602977: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 15:29:55.620832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747582195.643058   45784 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747582195.649648   45784 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 15:29:55.671655: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Currently logged in as: trial to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/wandb/run-20250518_153000-28ah0ooo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eval-baseline
# wandb: ⭐️ View project at https://wandb.ai/trial/di725-project
# wandb: 🚀 View run at https://wandb.ai/trial/di725-project/runs/28ah0ooo
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  4.57it/s]
# PTBTokenizer tokenized 52844 tokens at 270895.36 tokens per second.
# PTBTokenizer tokenized 27341 tokens at 193387.86 tokens per second.
# === Zero-Shot Baseline ===
# BLEU-4 : 0.0146
# CIDEr  : 0.1320
# GeoSim : 0.3719
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# wandb: ⢿ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⢿ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⢿ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⢿ uploading output.log 524B/524B (0.5s)
# wandb: ⢿ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⢿ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣻ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⣻ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⣻ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⣻ uploading output.log 524B/524B (0.5s)
# wandb: ⣻ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⣻ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣽ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⣽ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⣽ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⣽ uploading output.log 524B/524B (0.5s)
# wandb: ⣽ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⣽ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣾ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⣾ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⣾ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⣾ uploading output.log 524B/524B (0.5s)
# wandb: ⣾ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⣾ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣷ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⣷ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⣷ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⣷ uploading output.log 524B/524B (0.5s)
# wandb: ⣷ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⣷ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣯ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⣯ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⣯ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⣯ uploading output.log 524B/524B (0.5s)
# wandb: ⣯ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⣯ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣟ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⣟ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⣟ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⣟ uploading output.log 524B/524B (0.5s)
# wandb: ⣟ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⣟ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⡿ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⡿ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⡿ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⡿ uploading output.log 524B/524B (0.5s)
# wandb: ⡿ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⡿ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⢿ uploading media/images/sample_1_2_4aea62e2d26029686cfb.png 84.4KB/84...
# wandb: ⢿ uploading media/images/sample_2_3_74976d3aca781c097b01.png 87.0KB/87...
# wandb: ⢿ uploading media/images/sample_3_4_ccc9c76f04699f105a17.png 73.3KB/73...
# wandb: ⢿ uploading output.log 524B/524B (0.5s)
# wandb: ⢿ uploading wandb-summary.json 2.7KB/2.7KB (0.5s)
# wandb: ⢿ uploading config.yaml 1.2KB/1.2KB (0.3s)
# wandb: ⣻ uploading history steps 0-4, summary, console lines 2-9 (0.3s)
# wandb:
# wandb: ⣻ uploading history steps 0-4, summary, console lines 2-9 (0.3s)
# wandb:
# wandb: Run history:
# wandb:    eval/bleu ▁
# wandb:   eval/cider ▁
# wandb: eval/geo_sim ▁
# wandb:
# wandb: Run summary:
# wandb:    eval/bleu 0.01458
# wandb:   eval/cider 0.13197
# wandb: eval/geo_sim 0.37192
# wandb:
# wandb: 🚀 View run eval-baseline at: https://wandb.ai/trial/di725-project/runs/28ah0ooo
# wandb: ⭐️ View project at: https://wandb.ai/trial/di725-project
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250518_153000-28ah0ooo/logs

# %% [markdown]
# ## Evaluation of LoRA - Rank 8

# %%
# !python "/content/drive/MyDrive/DI 725 Project/evaluation.py" # adjust parameters of the script accordingly

# %% [raw]
# 2025-05-18 15:54:13.297876: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 15:54:13.315747: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747583653.337096   60321 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747583653.343547   60321 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 15:54:13.365289: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Currently logged in as: trial to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/wandb/run-20250518_155417-681iun04
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eval-lora-r8
# wandb: ⭐️ View project at https://wandb.ai/trial/di725-project
# wandb: 🚀 View run at https://wandb.ai/trial/di725-project/runs/681iun04
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  5.06it/s]
# PTBTokenizer tokenized 52844 tokens at 336786.08 tokens per second.
# PTBTokenizer tokenized 10165 tokens at 90957.01 tokens per second.
# === Evaluation Metrics ===
# BLEU-4 : 0.0000
# CIDEr  : 0.0413
# GeoSim : 0.1192
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# wandb:
# wandb:
# wandb: Run history:
# wandb:    eval/bleu ▁
# wandb:   eval/cider ▁
# wandb: eval/geo_sim ▁
# wandb:
# wandb: Run summary:
# wandb:    eval/bleu 0
# wandb:   eval/cider 0.04131
# wandb: eval/geo_sim 0.11917
# wandb:
# wandb: 🚀 View run eval-lora-r8 at: https://wandb.ai/trial/di725-project/runs/681iun04
# wandb: ⭐️ View project at: https://wandb.ai/trial/di725-project
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250518_155417-681iun04/logs

# %% [markdown]
# ## Evaluation of LoRA - Rank 4

# %%
# !python "/content/drive/MyDrive/DI 725 Project/evaluation.py" # adjust parameters of the script accordingly

# %% [markdown]
# ## Evaluation of LoRA - Rank 2

# %%
# !python "/content/drive/MyDrive/DI 725 Project/evaluation.py" # adjust parameters of the script accordingly

# %% [raw]
# 2025-05-18 15:38:48.061793: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 15:38:48.078379: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747582728.099330   56367 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747582728.105726   56367 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 15:38:48.126592: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Currently logged in as: trial to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/wandb/run-20250518_153852-rbnvh11o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eval-lora-r2-alpha-16
# wandb: ⭐️ View project at https://wandb.ai/trial/di725-project
# wandb: 🚀 View run at https://wandb.ai/trial/di725-project/runs/rbnvh11o
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  4.62it/s]
# PTBTokenizer tokenized 52844 tokens at 329863.33 tokens per second.
# PTBTokenizer tokenized 26717 tokens at 205371.72 tokens per second.
# === Evaluation Metrics ===
# BLEU-4 : 0.0000
# CIDEr  : 0.0110
# GeoSim : 0.0458
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# wandb:
# wandb:
# wandb: Run history:
# wandb:    eval/bleu ▁
# wandb:   eval/cider ▁
# wandb: eval/geo_sim ▁
# wandb:
# wandb: Run summary:
# wandb:    eval/bleu 0
# wandb:   eval/cider 0.01104
# wandb: eval/geo_sim 0.04579
# wandb:
# wandb: 🚀 View run eval-lora-r2-alpha-16 at: https://wandb.ai/trial/di725-project/runs/rbnvh11o
# wandb: ⭐️ View project at: https://wandb.ai/trial/di725-project
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250518_153852-rbnvh11o/logs

# %% [markdown]
# ## Evaluation of LoRA - LoRA Rank 2 - Alpha 4

# %%
# !python "/content/drive/MyDrive/DI 725 Project/evaluation.py" # adjust parameters of the script accordingly

# %% [raw]
# 2025-05-18 20:26:30.990476: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 20:26:31.007399: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747599991.028722    8455 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747599991.035188    8455 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 20:26:31.056548: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: trial to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.7
# wandb: Run data is saved locally in /content/wandb/run-20250518_202657-quhgdz0v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eval-lora-r2-alpha_4
# wandb: ⭐️ View project at https://wandb.ai/trial/di725-project
# wandb: 🚀 View run at https://wandb.ai/trial/di725-project/runs/quhgdz0v
# config.json: 100% 1.33k/1.33k [00:00<00:00, 6.24MB/s]
# model.safetensors.index.json: 100% 75.1k/75.1k [00:00<00:00, 4.13MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.99G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 10.5M/4.99G [00:00<02:10, 38.1MB/s]
# model-00001-of-00002.safetensors:   0% 21.0M/4.99G [00:00<01:35, 52.1MB/s]
# model-00001-of-00002.safetensors:   1% 31.5M/4.99G [00:00<01:17, 63.9MB/s]
# model-00001-of-00002.safetensors:   1% 52.4M/4.99G [00:00<00:56, 87.0MB/s]
# model-00001-of-00002.safetensors:   1% 73.4M/4.99G [00:00<00:44, 111MB/s]
# model-00001-of-00002.safetensors:   2% 94.4M/4.99G [00:00<00:36, 133MB/s]
# model-00001-of-00002.safetensors:   2% 115M/4.99G [00:01<00:32, 151MB/s]
# model-00001-of-00002.safetensors:   3% 147M/4.99G [00:01<00:28, 173MB/s]
# model-00001-of-00002.safetensors:   3% 168M/4.99G [00:01<00:26, 181MB/s]
# model-00001-of-00002.safetensors:   4% 199M/4.99G [00:01<00:25, 191MB/s]
# model-00001-of-00002.safetensors:   4% 220M/4.99G [00:01<00:24, 195MB/s]
# model-00001-of-00002.safetensors:   5% 252M/4.99G [00:01<00:23, 200MB/s]
# model-00001-of-00002.safetensors:   6% 283M/4.99G [00:01<00:23, 202MB/s]
# model-00001-of-00002.safetensors:   6% 304M/4.99G [00:01<00:23, 200MB/s]
# model-00001-of-00002.safetensors:   7% 325M/4.99G [00:02<00:30, 154MB/s]
# model-00001-of-00002.safetensors:   7% 346M/4.99G [00:02<00:28, 164MB/s]
# model-00001-of-00002.safetensors:   7% 367M/4.99G [00:02<00:26, 173MB/s]
# model-00001-of-00002.safetensors:   8% 398M/4.99G [00:02<00:24, 186MB/s]
# model-00001-of-00002.safetensors:   8% 419M/4.99G [00:02<00:24, 190MB/s]
# model-00001-of-00002.safetensors:   9% 440M/4.99G [00:02<00:23, 195MB/s]
# model-00001-of-00002.safetensors:   9% 472M/4.99G [00:02<00:22, 200MB/s]
# model-00001-of-00002.safetensors:  10% 493M/4.99G [00:03<00:22, 196MB/s]
# model-00001-of-00002.safetensors:  10% 514M/4.99G [00:03<00:23, 193MB/s]
# model-00001-of-00002.safetensors:  11% 535M/4.99G [00:03<00:23, 190MB/s]
# model-00001-of-00002.safetensors:  11% 556M/4.99G [00:03<00:22, 194MB/s]
# model-00001-of-00002.safetensors:  12% 577M/4.99G [00:03<00:22, 196MB/s]
# model-00001-of-00002.safetensors:  12% 598M/4.99G [00:03<00:22, 196MB/s]
# model-00001-of-00002.safetensors:  12% 619M/4.99G [00:03<00:22, 195MB/s]
# model-00001-of-00002.safetensors:  13% 650M/4.99G [00:03<00:21, 201MB/s]
# model-00001-of-00002.safetensors:  14% 682M/4.99G [00:03<00:21, 204MB/s]
# model-00001-of-00002.safetensors:  14% 703M/4.99G [00:04<00:21, 198MB/s]
# model-00001-of-00002.safetensors:  15% 734M/4.99G [00:04<00:20, 203MB/s]
# model-00001-of-00002.safetensors:  15% 765M/4.99G [00:04<00:20, 205MB/s]
# model-00001-of-00002.safetensors:  16% 786M/4.99G [00:04<00:21, 193MB/s]
# model-00001-of-00002.safetensors:  16% 807M/4.99G [00:04<00:21, 196MB/s]
# model-00001-of-00002.safetensors:  17% 828M/4.99G [00:04<00:21, 198MB/s]
# model-00001-of-00002.safetensors:  17% 849M/4.99G [00:04<00:20, 200MB/s]
# model-00001-of-00002.safetensors:  17% 870M/4.99G [00:04<00:20, 201MB/s]
# model-00001-of-00002.safetensors:  18% 891M/4.99G [00:05<00:20, 201MB/s]
# model-00001-of-00002.safetensors:  18% 912M/4.99G [00:05<00:20, 200MB/s]
# model-00001-of-00002.safetensors:  19% 933M/4.99G [00:05<00:20, 202MB/s]
# model-00001-of-00002.safetensors:  19% 954M/4.99G [00:05<00:19, 203MB/s]
# model-00001-of-00002.safetensors:  20% 975M/4.99G [00:05<00:19, 204MB/s]
# model-00001-of-00002.safetensors:  20% 996M/4.99G [00:05<00:19, 203MB/s]
# model-00001-of-00002.safetensors:  20% 1.02G/4.99G [00:05<00:19, 202MB/s]
# model-00001-of-00002.safetensors:  21% 1.04G/4.99G [00:05<00:19, 199MB/s]
# model-00001-of-00002.safetensors:  21% 1.06G/4.99G [00:05<00:19, 198MB/s]
# model-00001-of-00002.safetensors:  22% 1.08G/4.99G [00:05<00:19, 197MB/s]
# model-00001-of-00002.safetensors:  22% 1.10G/4.99G [00:06<00:19, 197MB/s]
# model-00001-of-00002.safetensors:  22% 1.12G/4.99G [00:06<00:19, 196MB/s]
# model-00001-of-00002.safetensors:  23% 1.14G/4.99G [00:06<00:19, 196MB/s]
# model-00001-of-00002.safetensors:  23% 1.16G/4.99G [00:06<00:19, 196MB/s]
# model-00001-of-00002.safetensors:  24% 1.18G/4.99G [00:06<00:19, 200MB/s]
# model-00001-of-00002.safetensors:  24% 1.21G/4.99G [00:06<00:19, 199MB/s]
# model-00001-of-00002.safetensors:  25% 1.23G/4.99G [00:06<00:19, 198MB/s]
# model-00001-of-00002.safetensors:  25% 1.25G/4.99G [00:06<00:19, 197MB/s]
# model-00001-of-00002.safetensors:  25% 1.27G/4.99G [00:06<00:18, 197MB/s]
# model-00001-of-00002.safetensors:  26% 1.29G/4.99G [00:07<00:18, 198MB/s]
# model-00001-of-00002.safetensors:  26% 1.31G/4.99G [00:07<00:18, 198MB/s]
# model-00001-of-00002.safetensors:  27% 1.33G/4.99G [00:07<00:18, 198MB/s]
# model-00001-of-00002.safetensors:  27% 1.35G/4.99G [00:07<00:18, 196MB/s]
# model-00001-of-00002.safetensors:  28% 1.37G/4.99G [00:07<00:18, 197MB/s]
# model-00001-of-00002.safetensors:  28% 1.39G/4.99G [00:07<00:18, 197MB/s]
# model-00001-of-00002.safetensors:  28% 1.42G/4.99G [00:07<00:18, 199MB/s]
# model-00001-of-00002.safetensors:  29% 1.44G/4.99G [00:07<00:17, 200MB/s]
# model-00001-of-00002.safetensors:  29% 1.46G/4.99G [00:07<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  30% 1.48G/4.99G [00:07<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  30% 1.50G/4.99G [00:08<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  30% 1.52G/4.99G [00:08<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  31% 1.54G/4.99G [00:08<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  31% 1.56G/4.99G [00:08<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  32% 1.58G/4.99G [00:08<00:17, 198MB/s]
# model-00001-of-00002.safetensors:  32% 1.60G/4.99G [00:08<00:16, 200MB/s]
# model-00001-of-00002.safetensors:  33% 1.63G/4.99G [00:08<00:16, 199MB/s]
# model-00001-of-00002.safetensors:  33% 1.65G/4.99G [00:08<00:16, 199MB/s]
# model-00001-of-00002.safetensors:  33% 1.67G/4.99G [00:08<00:16, 198MB/s]
# model-00001-of-00002.safetensors:  34% 1.69G/4.99G [00:09<00:16, 197MB/s]
# model-00001-of-00002.safetensors:  34% 1.71G/4.99G [00:09<00:16, 198MB/s]
# model-00001-of-00002.safetensors:  35% 1.73G/4.99G [00:09<00:16, 194MB/s]
# model-00001-of-00002.safetensors:  35% 1.75G/4.99G [00:09<00:16, 198MB/s]
# model-00001-of-00002.safetensors:  35% 1.77G/4.99G [00:09<00:16, 200MB/s]
# model-00001-of-00002.safetensors:  36% 1.79G/4.99G [00:09<00:15, 201MB/s]
# model-00001-of-00002.safetensors:  36% 1.81G/4.99G [00:09<00:15, 204MB/s]
# model-00001-of-00002.safetensors:  37% 1.84G/4.99G [00:09<00:15, 205MB/s]
# model-00001-of-00002.safetensors:  37% 1.87G/4.99G [00:09<00:15, 207MB/s]
# model-00001-of-00002.safetensors:  38% 1.89G/4.99G [00:10<00:14, 208MB/s]
# model-00001-of-00002.safetensors:  38% 1.91G/4.99G [00:10<00:14, 208MB/s]
# model-00001-of-00002.safetensors:  39% 1.93G/4.99G [00:10<00:20, 148MB/s]
# model-00001-of-00002.safetensors:  39% 1.95G/4.99G [00:10<00:26, 114MB/s]
# model-00001-of-00002.safetensors:  39% 1.97G/4.99G [00:10<00:32, 94.2MB/s]
# model-00001-of-00002.safetensors:  40% 1.99G/4.99G [00:11<00:30, 99.9MB/s]
# model-00001-of-00002.safetensors:  40% 2.01G/4.99G [00:11<00:32, 91.2MB/s]
# model-00001-of-00002.safetensors:  41% 2.03G/4.99G [00:11<00:38, 77.6MB/s]
# model-00001-of-00002.safetensors:  41% 2.04G/4.99G [00:11<00:39, 75.5MB/s]
# model-00001-of-00002.safetensors:  41% 2.07G/4.99G [00:12<00:34, 85.1MB/s]
# model-00001-of-00002.safetensors:  42% 2.08G/4.99G [00:12<00:33, 87.2MB/s]
# model-00001-of-00002.safetensors:  42% 2.09G/4.99G [00:12<00:50, 58.1MB/s]
# model-00001-of-00002.safetensors:  42% 2.11G/4.99G [00:12<00:37, 77.6MB/s]
# model-00001-of-00002.safetensors:  42% 2.12G/4.99G [00:12<00:36, 78.1MB/s]
# model-00001-of-00002.safetensors:  43% 2.13G/4.99G [00:13<00:36, 78.5MB/s]
# model-00001-of-00002.safetensors:  43% 2.14G/4.99G [00:13<00:39, 71.8MB/s]
# model-00001-of-00002.safetensors:  43% 2.15G/4.99G [00:13<00:39, 71.9MB/s]
# model-00001-of-00002.safetensors:  43% 2.17G/4.99G [00:13<00:34, 82.5MB/s]
# model-00001-of-00002.safetensors:  44% 2.18G/4.99G [00:13<00:33, 84.1MB/s]
# model-00001-of-00002.safetensors:  44% 2.19G/4.99G [00:13<00:33, 83.7MB/s]
# model-00001-of-00002.safetensors:  44% 2.20G/4.99G [00:13<00:33, 84.3MB/s]
# model-00001-of-00002.safetensors:  89% 4.44G/4.99G [00:29<00:05, 103MB/s]
# model-00001-of-00002.safetensors:  89% 4.46G/4.99G [00:29<00:04, 117MB/s]
# model-00001-of-00002.safetensors:  90% 4.48G/4.99G [00:29<00:03, 133MB/s]
# model-00001-of-00002.safetensors:  90% 4.50G/4.99G [00:29<00:03, 146MB/s]
# model-00001-of-00002.safetensors:  91% 4.52G/4.99G [00:29<00:03, 156MB/s]
# model-00001-of-00002.safetensors:  91% 4.54G/4.99G [00:29<00:02, 168MB/s]
# model-00001-of-00002.safetensors:  91% 4.56G/4.99G [00:29<00:02, 177MB/s]
# model-00001-of-00002.safetensors:  92% 4.58G/4.99G [00:29<00:02, 181MB/s]
# model-00001-of-00002.safetensors:  92% 4.60G/4.99G [00:30<00:02, 182MB/s]
# model-00001-of-00002.safetensors:  93% 4.62G/4.99G [00:30<00:02, 171MB/s]
# model-00001-of-00002.safetensors:  93% 4.66G/4.99G [00:30<00:01, 184MB/s]
# model-00001-of-00002.safetensors:  94% 4.68G/4.99G [00:30<00:01, 190MB/s]
# model-00001-of-00002.safetensors:  94% 4.70G/4.99G [00:30<00:01, 195MB/s]
# model-00001-of-00002.safetensors:  94% 4.72G/4.99G [00:30<00:01, 196MB/s]
# model-00001-of-00002.safetensors:  95% 4.74G/4.99G [00:30<00:01, 189MB/s]
# model-00001-of-00002.safetensors:  95% 4.76G/4.99G [00:30<00:01, 191MB/s]
# model-00001-of-00002.safetensors:  96% 4.78G/4.99G [00:30<00:01, 191MB/s]
# model-00001-of-00002.safetensors:  96% 4.80G/4.99G [00:31<00:00, 192MB/s]
# model-00001-of-00002.safetensors:  97% 4.82G/4.99G [00:31<00:00, 197MB/s]
# model-00001-of-00002.safetensors:  97% 4.84G/4.99G [00:31<00:00, 200MB/s]
# model-00001-of-00002.safetensors:  97% 4.87G/4.99G [00:31<00:00, 202MB/s]
# model-00001-of-00002.safetensors:  98% 4.89G/4.99G [00:31<00:00, 203MB/s]
# model-00001-of-00002.safetensors:  98% 4.91G/4.99G [00:31<00:00, 203MB/s]
# model-00001-of-00002.safetensors:  99% 4.93G/4.99G [00:31<00:00, 204MB/s]
# model-00001-of-00002.safetensors:  99% 4.96G/4.99G [00:31<00:00, 206MB/s]
# model-00001-of-00002.safetensors: 100% 4.99G/4.99G [00:32<00:00, 156MB/s]
# Downloading shards:  50% 1/2 [00:32<00:32, 32.22s/it]
# model-00002-of-00002.safetensors:   0% 0.00/1.07G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   3% 31.5M/1.07G [00:00<00:03, 285MB/s]
# model-00002-of-00002.safetensors:   6% 62.9M/1.07G [00:00<00:03, 284MB/s]
# model-00002-of-00002.safetensors:  10% 105M/1.07G [00:00<00:03, 307MB/s]
# model-00002-of-00002.safetensors:  14% 147M/1.07G [00:00<00:02, 312MB/s]
# model-00002-of-00002.safetensors:  18% 189M/1.07G [00:00<00:02, 325MB/s]
# model-00002-of-00002.safetensors:  22% 231M/1.07G [00:00<00:02, 324MB/s]
# model-00002-of-00002.safetensors:  25% 273M/1.07G [00:00<00:02, 325MB/s]
# model-00002-of-00002.safetensors:  29% 315M/1.07G [00:00<00:02, 321MB/s]
# model-00002-of-00002.safetensors:  33% 357M/1.07G [00:01<00:02, 325MB/s]
# model-00002-of-00002.safetensors:  37% 398M/1.07G [00:01<00:02, 324MB/s]
# model-00002-of-00002.safetensors:  41% 440M/1.07G [00:01<00:01, 323MB/s]
# model-00002-of-00002.safetensors:  45% 482M/1.07G [00:01<00:01, 324MB/s]
# model-00002-of-00002.safetensors:  49% 524M/1.07G [00:01<00:01, 327MB/s]
# model-00002-of-00002.safetensors:  53% 566M/1.07G [00:01<00:01, 327MB/s]
# model-00002-of-00002.safetensors:  57% 608M/1.07G [00:01<00:01, 315MB/s]
# model-00002-of-00002.safetensors:  61% 650M/1.07G [00:02<00:01, 319MB/s]
# model-00002-of-00002.safetensors:  65% 692M/1.07G [00:02<00:01, 320MB/s]
# model-00002-of-00002.safetensors:  69% 734M/1.07G [00:02<00:01, 323MB/s]
# model-00002-of-00002.safetensors:  72% 776M/1.07G [00:02<00:00, 323MB/s]
# model-00002-of-00002.safetensors:  76% 818M/1.07G [00:02<00:00, 323MB/s]
# model-00002-of-00002.safetensors:  80% 860M/1.07G [00:02<00:00, 324MB/s]
# model-00002-of-00002.safetensors:  84% 902M/1.07G [00:02<00:00, 325MB/s]
# model-00002-of-00002.safetensors:  88% 944M/1.07G [00:02<00:00, 325MB/s]
# model-00002-of-00002.safetensors:  92% 986M/1.07G [00:03<00:00, 326MB/s]
# model-00002-of-00002.safetensors:  96% 1.03G/1.07G [00:03<00:00, 329MB/s]
# model-00002-of-00002.safetensors: 100% 1.07G/1.07G [00:03<00:00, 322MB/s]
# Downloading shards: 100% 2/2 [00:35<00:00, 17.88s/it]
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  2.47it/s]
# generation_config.json: 100% 173/173 [00:00<00:00, 747kB/s]
# /usr/local/lib/python3.11/dist-packages/peft/config.py:162: UserWarning: Unexpected keyword arguments ['corda_config', 'trainable_token_indices'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# Downloading builder script: 100% 5.94k/5.94k [00:00<00:00, 19.1MB/s]
# Downloading extra modules: 4.07kB [00:00, 7.39MB/s]
# Downloading extra modules: 100% 3.34k/3.34k [00:00<00:00, 11.3MB/s]
# modules.json: 100% 349/349 [00:00<00:00, 1.46MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 629kB/s]
# README.md: 100% 10.4k/10.4k [00:00<00:00, 36.9MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 276kB/s]
# config.json: 100% 571/571 [00:00<00:00, 2.37MB/s]
# model.safetensors: 100% 438M/438M [00:01<00:00, 335MB/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 2.02MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 3.22MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 5.84MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 1.15MB/s]
# config.json: 100% 190/190 [00:00<00:00, 940kB/s]
# The 'batch_size' attribute of HybridCache is deprecated and will be removed in v4.49. Use the more precisely named 'self.max_batch_size' attribute instead.
# PTBTokenizer tokenized 52844 tokens at 298959.60 tokens per second.
# PTBTokenizer tokenized 26717 tokens at 204294.41 tokens per second.
# === Evaluation Metrics ===
# BLEU-4 : 0.0000
# CIDEr  : 0.0110
# GeoSim : 0.0458
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# wandb:
# wandb:
# wandb: Run history:
# wandb:    eval/bleu ▁
# wandb:   eval/cider ▁
# wandb: eval/geo_sim ▁
# wandb:
# wandb: Run summary:
# wandb:    eval/bleu 0
# wandb:   eval/cider 0.01104
# wandb: eval/geo_sim 0.04579
# wandb:
# wandb: 🚀 View run eval-lora-r2-alpha_4 at: https://wandb.ai/trial/di725-project/runs/quhgdz0v
# wandb: ⭐️ View project at: https://wandb.ai/trial/di725-project
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250518_202657-quhgdz0v/logs

# %% [markdown]
# ## Evaluation of LoRA - LoRA Rank 2 - Alpha 32

# %%
# !python "/content/drive/MyDrive/DI 725 Project/evaluation.py" # adjust parameters of the script accordingly

# %% [raw]
# 2025-05-18 15:13:51.850848: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 15:13:51.868166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747581231.889562   49894 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747581231.896038   49894 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 15:13:51.917187: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# wandb: Currently logged in as: trial to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/wandb/run-20250518_151356-buote8yx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eval-lora-r2-alpha-32
# wandb: ⭐️ View project at https://wandb.ai/trial/di725-project
# wandb: 🚀 View run at https://wandb.ai/trial/di725-project/runs/buote8yx
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  4.83it/s]
# PTBTokenizer tokenized 52844 tokens at 331276.26 tokens per second.
# PTBTokenizer tokenized 26717 tokens at 204017.14 tokens per second.
# === Evaluation Metrics ===
# BLEU-4 : 0.0000
# CIDEr  : 0.0110
# GeoSim : 0.0458
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# Figure(400x400)
# wandb:
# wandb:
# wandb: Run history:
# wandb:    eval/bleu ▁
# wandb:   eval/cider ▁
# wandb: eval/geo_sim ▁
# wandb:
# wandb: Run summary:
# wandb:    eval/bleu 0
# wandb:   eval/cider 0.01104
# wandb: eval/geo_sim 0.04579
# wandb:
# wandb: 🚀 View run eval-lora-r2-alpha-32 at: https://wandb.ai/trial/di725-project/runs/buote8yx
# wandb: ⭐️ View project at: https://wandb.ai/trial/di725-project
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250518_151356-buote8yx/logs

# %% [markdown]
# ## Evaluation of LoRA - LoRA Rank 2 - No Dropout

# %%
# !python "/content/drive/MyDrive/DI 725 Project/evaluation.py" # adjust parameters of the script accordingly
